# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('concrete (1).csv')
data.head()
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29

# %%
data.describe()
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# ...

# %% [markdown]
# ### Let's try to understand the shape of histograms of all these columns with just the 5 point summary of them.
# 1. Cement:Mean>Median= The distribution would be skewed towards right or positively skewed.
# 2. Slag:Mean>Median= Since mean is a lot larger than median, the distribution would be skewed towards right a lot.
# 3. Ash: Mean>Median= The distribution would again be skewed towards right.
# 4. Water:Median>Mean= The distribution would be skewed towards left, but since the difference between mean and median is not                         much, it would only be slightly skewed towards left.
# 5. Superplastic:Median>Mean= The median is very slightly greater than the mean. The distribution would be slightly skewed towards the left, but won't be noticeable
# 6. Coarseagg: Mean>Median= The distribution would be skewed towards right.
# 7. Fineagg: Median>Mean= The distribution would be skewed towards the left.
# 8. Age: Mean>Median= The distribution would be skewed towards the right.

# %% [markdown]
# ## Deliverable 1
# ### A. Univariate Analysis
# Univariate analysis – data types and description of the
# independent attributes which should include (name,
# meaning, range of values observed, central values (mean
# and median), standard deviation and quartiles, analysis of
# the body of distributions / tails, missing values, outliers
# ### Attributes' Information

# %%
columns=data.columns

# %% [markdown]
# ### Range of All Attributes

# %%
for i in columns:
    print('Range of {} column={}'.format(i,int(data[i].describe()[7])-int(data[i].describe()[3])))
# Out:
# Range of cement column=438
# Range of slag column=359
# Range of ash column=200
# Range of water column=126
# Range of superplastic column=32
# Range of coarseagg column=344
# Range of fineagg column=398
# Range of age column=364
# Range of strength column=80

# %% [markdown]
# ### Mean of All Attributes

# %%
for i in columns:
    print('Mean of {} column={}'.format(i,int(data[i].describe()[1])))
# Out:
# Mean of cement column=281
# Mean of slag column=73
# Mean of ash column=54
# Mean of water column=181
# Mean of superplastic column=6
# Mean of coarseagg column=972
# Mean of fineagg column=773
# Mean of age column=45
# Mean of strength column=35

# %% [markdown]
# ### Median of All Attributes

# %%
for i in columns:
    print('Median of {} column={}'.format(i,int(data[i].describe()[5])))
# Out:
# Median of cement column=272
# Median of slag column=22
# Median of ash column=0
# Median of water column=185
# Median of superplastic column=6
# Median of coarseagg column=968
# Median of fineagg column=779
# Median of age column=28
# Median of strength column=34

# %% [markdown]
# ### Standard Deviation of All Attributes

# %%
for i in columns:
    print('Standard Deviation of {} column={}'.format(i,int(data[i].describe()[2])))
# Out:
# Standard Deviation of cement column=104
# Standard Deviation of slag column=86
# Standard Deviation of ash column=63
# Standard Deviation of water column=21
# Standard Deviation of superplastic column=5
# Standard Deviation of coarseagg column=77
# Standard Deviation of fineagg column=80
# Standard Deviation of age column=63
# Standard Deviation of strength column=16

# %% [markdown]
# ### 1st Quartile or 25th Percentile of All Attributes

# %%
for i in columns:
    print('1st Quartile of {} column={}'.format(i,int(data[i].describe()[4])))
# Out:
# 1st Quartile of cement column=192
# 1st Quartile of slag column=0
# 1st Quartile of ash column=0
# 1st Quartile of water column=164
# 1st Quartile of superplastic column=0
# 1st Quartile of coarseagg column=932
# 1st Quartile of fineagg column=730
# 1st Quartile of age column=7
# 1st Quartile of strength column=23

# %% [markdown]
# ### 3rd Quartile of 75th Percentile of All Attributes

# %%
for i in columns:
    print('3rd Quartile of {} column={}'.format(i,int(data[i].describe()[6])))
# Out:
# 3rd Quartile of cement column=350
# 3rd Quartile of slag column=142
# 3rd Quartile of ash column=118
# 3rd Quartile of water column=192
# 3rd Quartile of superplastic column=10
# 3rd Quartile of coarseagg column=1029
# 3rd Quartile of fineagg column=824
# 3rd Quartile of age column=56
# 3rd Quartile of strength column=46

# %%
for i in columns:
    print('Missing Values in {} column={}'.format(i,data[i].isnull().any()))
# Out:
# Missing Values in cement column=False
# Missing Values in slag column=False
# Missing Values in ash column=False
# Missing Values in water column=False
# Missing Values in superplastic column=False
# Missing Values in coarseagg column=False
# Missing Values in fineagg column=False
# Missing Values in age column=False
# Missing Values in strength column=False

# %% [markdown]
# ### Distribution of Cement

# %%
sns.distplot(data['cement'])

# %%
sns.boxplot(data['cement'])

# %% [markdown]
# ### Distribution of Slag column

# %%
sns.distplot(data['slag'])

# %%
sns.boxplot(data['slag'])

# %% [markdown]
# ### Distribution of Ash Column

# %%
sns.distplot(data['ash'])

# %%
sns.boxplot(data['ash'])

# %% [markdown]
# ### Distribution of Water

# %%
sns.distplot(data['water'])

# %%
sns.boxplot(data['water'])

# %% [markdown]
# ### Distribution of Superplastic column

# %%
sns.distplot(data['superplastic'])

# %%
sns.boxplot(data['superplastic'])

# %% [markdown]
# ### Distribution of Coarseagg column

# %%
sns.distplot(data['coarseagg'])

# %%
sns.boxplot(data['coarseagg'])

# %% [markdown]
# ### Distribution of Fineagg column

# %%
sns.distplot(data['fineagg'])

# %%
sns.boxplot(data['fineagg'])

# %% [markdown]
# ### Distribution of age column

# %%
sns.distplot(data['age'])

# %%
sns.boxplot(data['age'])

# %% [markdown]
# ### Skewness of All Columns

# %%
for i in columns:
    print('The skewness of {} column is {}'.format(i,data[i].skew()))
# Out:
# The skewness of cement column is 0.5094811788717731
# The skewness of slag column is 0.8007168956061774
# The skewness of ash column is 0.5373539058066844
# The skewness of water column is 0.07462838428549402
# The skewness of superplastic column is 0.9072025748672466
# The skewness of coarseagg column is -0.04021974481106704
# The skewness of fineagg column is -0.25300959769707143
# The skewness of age column is 3.2691774006345895
# The skewness of strength column is 0.41697728841071807

# %% [markdown]
# ### B. Multivariate Analysis
# 1. Bi-variate analysis between the predictor variables and between the predictor variables and target column. Comment on your findings in terms of their relationship and degree of relation if any. Presence of leverage points. Visualize the analysis using boxplots and pair plots, histograms or density curves. Select the most appropriate attributes

# %%
for i in columns[:-1]:
        print(sns.jointplot(data[i],data['strength']))

# %% [markdown]
# ###### Findings
# 1. Strength and Cement: There seems to be no correlation between them. There seems to be no outliers present either.
# 2. Strength and Slag: There seems to be no correlation here too. There seems to be a few outliers present.
# 3. Strength and Ash: No correlation, no outliers.
# 4. Strength and Water: No correlation, a few outliers.
# 5. Strength and Superplastic: No correlation, a few outliers.
# 6. Strength and Coarseagg: No correation, no outliers
# 7. Strength and Fineagg: No correlation, a few outliers
# 8. Strength and Age: No correlation, no outliers

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(data)

# %% [markdown]
# ### C. Managing outliers and missing values
# Here, since there are no missing values, we will just fous on managin outliers.

# %%
from scipy import stats
import numpy as np
z=np.abs(stats.zscore(data))
print(z)
# Out:
# [[1.33901711 1.60144087 0.84714393 ... 0.31296991 0.27973311 0.35501811]
#  [1.07479007 0.36754132 1.09607803 ... 0.28226038 0.50146528 0.73710825]
#  [0.29838379 0.85688789 0.64896501 ... 1.09337085 0.27973311 0.39514356]
#  ...
#  [0.04564488 0.4882354  0.56454507 ... 0.06589318 0.27973311 0.50678082]
#  [0.58237302 0.41624406 0.84714393 ... 1.29254178 3.55306569 1.15238141]
#  [2.47791487 0.85688789 0.84714393 ... 2.00382326 0.61233136 1.005654  ]]

# %%
threshold=3
np.where(z>threshold)
# Out:
# (array([  21,   44,   64,   66,  133,  149,  156,  157,  159,  198,  232,
#          256,  262,  263,  270,  292,  297,  313,  323,  361,  393,  448,
#          465,  484,  538,  564,  570,  601,  623,  632,  713,  720,  744,
#          754,  755,  816,  838,  850,  878,  901,  918,  919,  951,  955,
#          957,  990,  995, 1026, 1028], dtype=int64),
#  array([1, 4, 7, 3, 7, 7, 4, 7, 7, 7, 4, 7, 7, 3, 7, 4, 7, 7, 7, 7, 7, 7,
#         7, 7, 4, 1, 7, 7, 7, 7, 7, 7, 4, 7, 7, 4, 4, 7, 7, 7, 1, 7, 7, 4,
#         7, 1, 7, 4, 7], dtype=int64))

# %%
np.where(z>threshold)[0].shape
# Out:
# (49,)

# %%
print(z[21][1])
# Out:
# 3.1100662151764396

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# cement          157.625
# slag            142.950
# ash             118.300
# water            27.100
# superplastic     10.200
# coarseagg        97.400
# fineagg          93.050
# age              49.000
# strength         22.425
# dtype: float64

# %%
np.where((data<(Q1-1.5*IQR))|(data>(Q3+1.5*IQR)))
# Out:
# (array([  44,   51,   64,   66,   93,   99,  103,  129,  133,  144,  149,
#          152,  156,  157,  159,  192,  198,  199,  207,  232,  256,  262,
#          263,  270,  292,  297,  302,  312,  313,  323,  359,  361,  370,
#          393,  432,  447,  448,  462,  465,  484,  504,  538,  539,  570,
#          581,  584,  587,  594,  601,  620,  622,  623,  632,  642,  696,
#          713,  720,  721,  732,  740,  744,  754,  755,  776,  789,  816,
#          826,  838,  850,  857,  861,  878,  900,  901,  914,  918,  919,
#          950,  951,  955,  957,  971,  985,  990,  995, 1003, 1017, 1026,
#         1028], dtype=int64),
#  array([4, 7, 7, 3, 7, 7, 7, 6, 7, 7, 7, 7, 4, 7, 7, 8, 7, 7, 7, 4, 7, 7,
#         3, 7, 4, 7, 7, 7, 7, 7, 7, 7, 7, 7, 3, 6, 7, 3, 7, 7, 6, 4, 7, 7,
#         7, 6, 3, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 8, 3, 4, 7, 7, 7, 3, 4,
#         3, 4, 7, 6, 7, 7, 7, 7, 3, 1, 7, 8, 7, 4, 7, 7, 7, 1, 7, 8, 7, 4,
#         7], dtype=int64))

# %% [markdown]
# ### Correcting, Removing Outliers

# %%
data1=data[(z<3).all(axis=1)]
data.shape,data1.shape
# Out:
# ((1030, 9), (981, 9))

# %%
data2=data.copy()
for i,j in zip(np.where(z>threshold)[0],np.where(z>threshold)[1]):
               data2.iloc[i,j]=data.iloc[:,j].median()

# %%
data2.describe()
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    72.619126    54.188350   181.446990      5.973592
# std     104.506364    84.585573    63.997004    21.158975      5.477165
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.500000   118.300000   192.000000     10.075000
# max     540.000000   316.100000   200.100000   237.000000     23.400000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    36.093204    35.817961
# std      77.753954    80.175980    36.185504    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# ...

# %% [markdown]
# We can observe that the standard deviation has changed when we compare data2.describe() and data.describe()

# %%
z1=np.abs(stats.zscore(data2))
np.where(z1>threshold)[0].shape
# Out:
# (31,)

# %% [markdown]
# We can also observe that the number of outliers has decreased

# %% [markdown]
# ### 2. Deliverable-2
# #### a. Identify opportunities (if any) to create a composite feature, drop a feature

# %%
data2.corr()
# Out:
#                 cement      slag       ash     water  superplastic  coarseagg  \
# cement        1.000000 -0.273901 -0.397467 -0.079932      0.013336  -0.109349
# slag         -0.273901  1.000000 -0.317267  0.106164      0.069795  -0.284943
# ash          -0.397467 -0.317267  1.000000 -0.260872      0.447492  -0.009961
# water        -0.079932  0.106164 -0.260872  1.000000     -0.640110  -0.175195
# superplastic  0.013336  0.069795  0.447492 -0.640110      1.000000  -0.224503
# coarseagg    -0.109349 -0.284943 -0.009961 -0.175195     -0.224503   1.000000
# fineagg      -0.222718 -0.267566  0.079108 -0.449256      0.194806  -0.178481
# age           0.026391 -0.048707 -0.045360  0.094470     -0.068109   0.023420
# strength      0.497832  0.141306 -0.105755 -0.289857      0.346260  -0.164935
#
#                fineagg       age  strength
# cement       -0.222718  0.026391  0.497832
# slag         -0.267566 -0.048707  0.141306
# ash           0.079108 -0.045360 -0.105755
# ...

# %%
sns.heatmap(data2.corr(),annot=True)

# %% [markdown]
# As we saw from the pairplot too, there is no correlation at all amongst independent variables and hardly in independent and dependent variable, only in cement & strength.
# We can't deduce if we should remove any attribute as of now. Let's build a model and move ahead to see.

# %% [markdown]
# #### b. Decide on complexity of the model, should it be simple linear mode in terms of parameters or would a quadratic or higher degree help

# %%
y = data2[['strength']]
X = data2.drop(labels= "strength" , axis = 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.30, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
from sklearn.metrics import mean_squared_error, r2_score

# %%
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model1.score(X_train,y_train)
# Out:
# 0.6654796494834669

# %%
model1.score(X_test,y_test)
# Out:
# 0.6542200050385425

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, model1.coef_[0][idx]))
# Out:
# The coefficient for cement is 0.11067417218195597
# The coefficient for slag is 0.08343688544512357
# The coefficient for ash is 0.05233760787162534
# The coefficient for water is -0.14346630324520643
# The coefficient for superplastic is 0.45664620405043305
# The coefficient for coarseagg is 0.005502897746141055
# The coefficient for fineagg is 0.003271257591921075
# The coefficient for age is 0.2156019929697819

# %%
intercept=model1.intercept_[0]
print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is 3.3348793022326007

# %%
y_pred1 = model1.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test,y_pred1))
r2 = r2_score(y_test,y_pred1)
print(rmse)
print(r2)
# Out:
# 10.03173251470012
# 0.6542200050385425

# %%
from sklearn.preprocessing import PolynomialFeatures

polynomial_features = PolynomialFeatures(3)

X_train_poly = polynomial_features.fit_transform(X_train)
X_test_poly = polynomial_features.fit_transform(X_test)

model2 = LinearRegression()
model2.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
print(model2.score(X_train_poly,y_train))
# Out:
# 0.9381775593914738

# %%
print(model2.score(X_test_poly,y_test))
# Out:
# 0.8524787833273985

# %%
y_pred2 = model.predict(X_test_poly)

rmse = np.sqrt(mean_squared_error(y_test,y_pred2))
r2 = r2_score(y_test,y_pred2)
print(rmse)
print(r2)
#Initialize Result Array for summary
result = pd.DataFrame({'Model' : ['Linear Regression'], 'RMS' : [rmse], 'r2' : [r2],
                      'Comments' : 'Low accuracy explains [r2] percent fit and high error'})
# Out:
# 6.552443043960196
# 0.8524787833273985

# %% [markdown]
# Degree 3 is fitting well. We'll keep it.

# %%
X_poly = polynomial_features.fit_transform(X)
X_poly.shape
# Out:
# (1030, 165)

# %% [markdown]
# ### c. Explore for gaussians. If data is likely to be a mix of gaussians, explore individual clusters and present your findings in terms of the independent attributes and their suitability to predict strength

# %%
#### LEts check cluster for each variable vs target
plt.figure()
for column in data.select_dtypes(include=[np.number]):
    joint_plot = sns.jointplot(x=data[column], y=data['strength'], data=data, kind='kde');

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
Z = linkage(X_poly, 'ward', metric='euclidean')
Z.shape
# Out:
# (1029, 4)

# %%
plt.figure(figsize=(25, 10))
dendrogram(Z)
plt.show()

# %%
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=3,  # show only the last p merged clusters
)
plt.show()

# %% [markdown]
# ##### It looks like there are no clusters when we check with the POLY X
# ## 3. Deliverable -3 (create the model )
# #### a. Obtain feature importance for the individual features using multiple methods and present your findings

# %%
from sklearn.ensemble import ExtraTreesRegressor

# Build a forest and compute the feature importances
forest = ExtraTreesRegressor(n_estimators=250,
                              random_state=0)

forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

header = list(X.columns)

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d %s (%f)" % (f + 1, indices[f], header[indices[f]], importances[indices[f]]))
# Out:
# <ipython-input-147-df93112e396f>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X, y)
# Feature ranking:
# 1. feature 7 age (0.354787)
# 2. feature 0 cement (0.260313)
# 3. feature 3 water (0.092926)
# 4. feature 4 superplastic (0.088063)
# 5. feature 1 slag (0.086605)
# 6. feature 6 fineagg (0.043926)
# 7. feature 2 ash (0.040773)
# 8. feature 5 coarseagg (0.032607)

# %%
forest.fit(X_poly, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_poly.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
# Out:
# <ipython-input-148-aa1f7bc0410f>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_poly, y)
# Feature ranking:
# 1. feature 140 (0.075216)
# 2. feature 16 (0.072732)
# 3. feature 52 (0.072359)
# 4. feature 79 (0.057317)
# 5. feature 74 (0.052082)
# 6. feature 49 (0.050957)
# 7. feature 77 (0.049739)
# 8. feature 70 (0.045392)
# 9. feature 8 (0.021318)
# 10. feature 133 (0.018050)
# 11. feature 46 (0.014371)
# 12. feature 41 (0.014154)
# 13. feature 80 (0.013416)
# 14. feature 9 (0.013385)
# 15. feature 13 (0.012147)
# 16. feature 72 (0.011593)
# 17. feature 1 (0.010610)
# 18. feature 45 (0.010128)
# 19. feature 51 (0.009745)
# 20. feature 34 (0.009195)
# 21. feature 58 (0.009161)
# 22. feature 43 (0.008892)
# 23. feature 141 (0.008560)
# 24. feature 67 (0.007810)
# 25. feature 33 (0.007729)
# 26. feature 76 (0.007607)
# 27. feature 159 (0.007607)
# ...

# %% [markdown]
# ### Method 1 :: Using extra trees regressor ensemble for checking feature importance on both X and X_Poly..¶
# for Non-Poly, the age and cement seem to be very important features
#
# Feature ranking:
#
# 1. feature 7 age (0.362571)
# 2. feature 0 cement (0.251731)
# 3. feature 4 superplastic (0.093553)
# for Poly, its difficult to see what derivative is important.. but its listed in descending order
#
# Feature ranking:
#
# 1. feature 8 (0.123953)
# 2. feature 1 (0.090699)
# 3. feature 114 (0.050513)
# 4. feature 164 (0.039432)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

lr = LinearRegression()
lr.fit(X_train, y_train)
rr = Ridge(alpha=0.2) # higher the alpha value, more restriction on the coefficients; low alpha > more generalization, coefficients are barely
# restricted and in this case linear and ridge regression resembles
rr.fit(X_train, y_train)
train_score=lr.score(X_train, y_train)
test_score=lr.score(X_test, y_test)
Ridge_train_score = rr.score(X_train,y_train)
Ridge_test_score = rr.score(X_test, y_test)
coeff_used = np.sum(rr.coef_!=0)


print ("linear regression train score: ", train_score)
print ("linear regression test score: ", test_score)

print ("ridge regression train score low alpha: ", Ridge_train_score)
print ("ridge regression test score low alpha: ", Ridge_test_score)
print ("number of features used: for low alpha", coeff_used)
# Out:
# linear regression train score:  0.6654796494834669
# linear regression test score:  0.6542200050385425
# ridge regression train score low alpha:  0.665479649478647
# ridge regression test score low alpha:  0.6542201861733432
# number of features used: for low alpha 8

# %%
from sklearn.linear_model import Lasso

lasso02 = Lasso(alpha=0.02, max_iter=10e5)
lasso02.fit(X_train,y_train)
train_score02=lasso02.score(X_train,y_train)
test_score02=lasso02.score(X_test,y_test)
coeff_used02 = np.sum(lasso02.coef_!=0)
print ("training score for alpha=0.02:", train_score02 )
print ("test score for alpha =0.02: ", test_score02)
print ("number of features used: for alpha =0.02:", coeff_used02)

#print (lasso02.coef_)

print("Feature ranking low alpha lasso:")

indices = np.argsort(lasso02.coef_)[::-1]

header = list(X.columns)

for f in range(X.shape[1]):
    print("%d. feature %d %s (%f)" % (f + 1, indices[f], header[indices[f]], lasso02.coef_[indices[f]]))
    
rmse = mean_squared_error(y_test,lasso02.predict(X_test))
r2 = r2_score(y_test,lasso02.predict(X_test))

result.loc[4] = ['Linear Reg lasso (alpha=0.02)', rmse, r2, 'low accuracy and high error']
# Out:
# training score for alpha=0.02: 0.6654795524710748
# test score for alpha =0.02:  0.6542579469200767
# number of features used: for alpha =0.02: 8
# Feature ranking low alpha lasso:
# 1. feature 4 superplastic (0.455159)
# 2. feature 7 age (0.215590)
# 3. feature 0 cement (0.110664)
# 4. feature 1 slag (0.083427)
# 5. feature 2 ash (0.052358)
# 6. feature 5 coarseagg (0.005457)
# 7. feature 6 fineagg (0.003243)
# 8. feature 3 water (-0.143714)

# %%
lasso2 = Lasso(alpha=0.2, max_iter=10e5)
lasso2.fit(X_train,y_train)
train_score2=lasso2.score(X_train,y_train)
test_score2=lasso2.score(X_test,y_test)
coeff_used2 = np.sum(lasso2.coef_!=0)
print ("training score for alpha=0.2:", train_score2 )
print ("test score for alpha =0.2: ", test_score2)
print ("number of features used: for alpha =0.2:", coeff_used2)

#print (lasso02.coef_)

print("Feature ranking low alpha lasso:")

indices = np.argsort(lasso2.coef_)[::-1]

header = list(X.columns)

for f in range(X.shape[1]):
    print("%d. feature %d %s (%f)" % (f + 1, indices[f], header[indices[f]], lasso2.coef_[indices[f]]))
    
rmse = mean_squared_error(y_test,lasso2.predict(X_test))
r2 = r2_score(y_test,lasso2.predict(X_test))

result.loc[5] = ['Linear Reg lasso(alpha=0.2)', rmse, r2, 'very low accuracy and low error']
# Out:
# training score for alpha=0.2: 0.665469949427153
# test score for alpha =0.2:  0.6545912323542772
# number of features used: for alpha =0.2: 8
# Feature ranking low alpha lasso:
# 1. feature 4 superplastic (0.441772)
# 2. feature 7 age (0.215481)
# 3. feature 0 cement (0.110572)
# 4. feature 1 slag (0.083342)
# 5. feature 2 ash (0.052538)
# 6. feature 5 coarseagg (0.005041)
# 7. feature 6 fineagg (0.002988)
# 8. feature 3 water (-0.145945)

# %% [markdown]
# ## Method 2. Ridge, Lasso..
# Using Ridge and lasso, we can see that we get different important featuers.. But lasso accuracy for 0.2 have dropped badly., hence it might not be good idea.

# %%
lr = LinearRegression()
lr.fit(X_train_poly, y_train)
rr = Ridge(alpha=0.2) # higher the alpha value, more restriction on the coefficients; low alpha > more generalization, coefficients are barely
# restricted and in this case linear and ridge regression resembles
rr.fit(X_train_poly, y_train)
train_score=lr.score(X_train_poly, y_train)
test_score=lr.score(X_test_poly, y_test)
Ridge_train_score = rr.score(X_train_poly,y_train)
Ridge_test_score = rr.score(X_test_poly, y_test)
coeff_used = np.sum(rr.coef_!=0)


print ("linear regression train score: ", train_score)
print ("linear regression test score: ", test_score)

print ("ridge regression train score low alpha: ", Ridge_train_score)
print ("ridge regression test score low alpha: ", Ridge_test_score)
print ("number of features used: for low alpha", coeff_used)


#print (rr.coef_)

indices = np.argsort(rr.coef_)[::-1]


    
rmse = mean_squared_error(y_test,rr.predict(X_test_poly))
r2 = r2_score(y_test,rr.predict(X_test_poly))

result.loc[6] = ['Linear Reg ridge (poly=3)(alpha=0.2)', rmse, r2, 'High accuracy']
# Out:
# linear regression train score:  0.9381775593914738
# linear regression test score:  0.8524787833273985
# ridge regression train score low alpha:  0.9358838992982165
# ridge regression test score low alpha:  0.8490504142974774
# number of features used: for low alpha 164
# C:\Users\Kushagra\anaconda31\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.94487e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,

# %%
from sklearn.linear_model import Lasso

lasso02 = Lasso(alpha=0.02, max_iter=10e5)
lasso02.fit(X_train_poly,y_train)
train_score02=lasso02.score(X_train_poly,y_train)
test_score02=lasso02.score(X_test_poly,y_test)
coeff_used02 = np.sum(lasso02.coef_!=0)
print ("training score for alpha=0.02:", train_score02 )
print ("test score for alpha =0.02: ", test_score02)
print ("number of features used: for alpha =0.02:", coeff_used02)

#print (lasso02.coef_)

print("Feature ranking low alpha lasso:")

indices = np.argsort(lasso02.coef_)[::-1]

for f in range(X_poly.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], lasso02.coef_[indices[f]]))

rmse = mean_squared_error(y_test,lasso02.predict(X_test_poly))
r2 = r2_score(y_test,lasso02.predict(X_test_poly))

result.loc[7] = ['Linear Reg ridge (poly=3)(alpha=0.02)', rmse, r2, 'good accuracy']
# Out:
# training score for alpha=0.02: 0.9313746253712376
# test score for alpha =0.02:  0.8393369107588388
# number of features used: for alpha =0.02: 158
# Feature ranking low alpha lasso:
# 1. feature 38 (0.615633)
# 2. feature 26 (0.467348)
# 3. feature 30 (0.026732)
# 4. feature 7 (0.025019)
# 5. feature 23 (0.019035)
# 6. feature 13 (0.018913)
# 7. feature 37 (0.017350)
# 8. feature 10 (0.010297)
# 9. feature 34 (0.005348)
# 10. feature 22 (0.003037)
# 11. feature 11 (0.003031)
# 12. feature 16 (0.002929)
# 13. feature 15 (0.002319)
# 14. feature 43 (0.002061)
# 15. feature 145 (0.001668)
# 16. feature 33 (0.001083)
# 17. feature 14 (0.000923)
# 18. feature 147 (0.000822)
# 19. feature 28 (0.000764)
# 20. feature 99 (0.000726)
# 21. feature 39 (0.000560)
# 22. feature 131 (0.000414)
# 23. feature 148 (0.000278)
# 24. feature 67 (0.000127)
# 25. feature 137 (0.000104)
# 26. feature 154 (0.000092)
# 27. feature 95 (0.000080)
# 28. feature 84 (0.000043)
# 29. feature 164 (0.000040)
# ...

# %% [markdown]
# ## 4. Deliverable -4 (Tuning the model)
# a. Algorithms that you think will be suitable for this project

# %%
### we shall try to PCA the  POLY.. 

from sklearn.decomposition import PCA 

pca = PCA(n_components=25)
pca.fit(X_poly)

print(pca.explained_variance_)

print(pca.explained_variance_ratio_)

plt.bar(list(range(1,26)),pca.explained_variance_ratio_,alpha=0.5, align='center')
plt.ylabel('Variation explained')
plt.xlabel('eigen Value')
plt.show()
# Out:
# [6.61193698e+16 4.14076378e+16 2.80499605e+16 1.24284620e+16
#  3.38296653e+15 2.71041377e+15 6.31362654e+14 2.78485127e+14
#  2.35748907e+14 1.94180250e+14 1.38916209e+14 9.09141535e+13
#  5.85901155e+13 5.14487095e+13 4.35975152e+13 3.63736440e+13
#  2.20356540e+13 1.86940208e+13 1.72292144e+13 1.53492147e+13
#  1.43410720e+13 1.07020838e+13 8.15406347e+12 7.63187209e+12
#  4.53115723e+12]
# [4.23867413e-01 2.65449419e-01 1.79818172e-01 7.96743833e-02
#  2.16869772e-02 1.73754843e-02 4.04743807e-03 1.78526762e-03
#  1.51130114e-03 1.24481949e-03 8.90541672e-04 5.82817821e-04
#  3.75600081e-04 3.29819105e-04 2.79487933e-04 2.33178302e-04
#  1.41262623e-04 1.19840619e-04 1.10450274e-04 9.83982749e-05
#  9.19354358e-05 6.86071963e-05 5.22727575e-05 4.89251771e-05
#  2.90476133e-05]

# %%
plt.step(list(range(1,26)),np.cumsum(pca.explained_variance_ratio_), where='mid')
plt.ylabel('Cumulative of variation explained')
plt.xlabel('eigen Value')
plt.show()

# %%
# 95 Per cent qantification
print(pca.explained_variance_ratio_.cumsum())
# Out:
# [0.42386741 0.68931683 0.869135   0.94880939 0.97049636 0.98787185
#  0.99191929 0.99370455 0.99521585 0.99646067 0.99735122 0.99793403
#  0.99830963 0.99863945 0.99891894 0.99915212 0.99929338 0.99941322
#  0.99952367 0.99962207 0.99971401 0.99978261 0.99983489 0.99988381
#  0.99991286]

# %% [markdown]
# ### Looks like to capture 95% of the of variance we need 25 components (out of 145+ poly featureS)

# %%
X_poly_pca = pca.transform(X_poly)
X_poly_pca.shape
# Out:
# (1030, 25)

# %%
# Lets try to fit the same poly model as earlier to check accuracy and confirm if PCA is sufficient.

X_poly_PCA_train, X_poly_PCA_test, y_train, y_test = train_test_split(X_poly_pca, y, test_size=0.30, random_state=1)


model = LinearRegression()
model.fit(X_poly_PCA_train, y_train)
y_poly_PCA_pred = model.predict(X_poly_PCA_test)

rmse = np.sqrt(mean_squared_error(y_test,y_poly_PCA_pred))
r2 = r2_score(y_test,y_pred2)
print(rmse) # non pca value  0.36
print(r2) #non pca value 0.87 

result.loc[8] = ['Linear Reg ridge (PCA=25)', rmse, r2, 'good accuracy']
# Out:
# 8.066213587814445
# 0.8524787833273985
